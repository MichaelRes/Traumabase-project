# %%
import numpy as np 
import pandas as pd 
import yaml

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from scipy.stats import norm

from sklearn.model_selection import StratifiedShuffleSplit, KFold, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.impute import SimpleImputer

from sklearn.linear_model import Lasso, Ridge, SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
import lightgbm as lgb
import os as os

import explore_data as exp  # all function to quickly explore the data
import df_pipeline as dfp

import warnings

pd.set_option('max_columns', 200)

# %%
# %matplotlib inline
os.chdir('C:\\Users\\haju1\\OneDrive\\Documents\\COURS\\Cours 3A\\Statistics in R\\PROJET\\')
dataset = pd.read_csv('4_computed_dataset.csv')
columns = dataset.columns
for names in columns :
    print(names)
# Out:
# ID_PATIENT
# Numéro de centre
# DATE_ENTREE
# Age du patient (ans)
# Sexe
# BMI
# Mécanisme en cause
# Casque
# Gants
# Intentionnalité
# Origine du patient
# SAMU: département
# SMUR (SAMU Ville)
# Éjection du véhicule
# Passager décédé dans le même véhicule
# Appréciation globale
# Incarcération
# Durée de l incarcération (min)
# Cinétique non-spécifié/non-évaluable
# Écrasé/projeté
# Chute
# Blast
# Ischémie du membre
# Amputation
# Fracas du bassin
# Brulûre
# Surface corporelle brulée
# Annoncé comme instable
# ASA-PS
# Grossesse, 2e ou 3e trimestre
# Traitement anticoagulant
# Traitement antiagrégants
# Glasgow initial
# Glasgow moteur initial
# Mode de transport à l´hôpital
# Anomalie pupillaire (Pré-hospitalier)
# Suspicion d atteinte neurologique à l examen
# Mannitol / SSH
# Régression mydriase sous osmothérapie
# Arrêt cardio-respiratoire (massage)
# Pression Artérielle Systolique (PAS) à l arrivée du SMUR
# Pression Artérielle Diastolique (PAD) à l arrivée du SMUR
# ...

# %%
dataset.loc[:,'Décès']
# Out:
# 0        Non
# 1        Non
# 2        Non
# 3        Non
# 4        Non
# 5        Non
# 6        Non
# 7        Non
# 8        Non
# 9        Non
# 10       Non
# 11       Non
# 12       Non
# 13       Non
# 14       Non
# 15       Non
# 16       Non
# 17       Non
# 18       Non
# 19       Non
# 20       Non
# 21       Oui
# 22       Non
# 23       Non
# 24       Non
# 25       Non
# 26       Non
# 27       Non
# 28       Non
# 29       Non
#         ...
# 20007    Non
# 20008    Non
# 20009    Non
# 20010    Non
# 20011    Non
# 20012    Non
# 20013    Non
# 20014    Non
# 20015    Non
# 20016    Non
# 20017    Non
# 20018    Non
# 20019    NaN
# 20020    Non
# 20021    Non
# 20022    Non
# 20023    Non
# 20024    Non
# 20025    Oui
# 20026    Oui
# 20027    Non
# 20028    Oui
# 20029    Non
# 20030    Non
# 20031    Non
# 20032    Non
# 20033    Non
# 20034    Non
# 20035    Non
# 20036    Non
# Name: Décès, Length: 20037, dtype: object

# %%
# %matplotlib inline

with open('C:\\Users\\haju1\\OneDrive\\Documents\\COURS\\Cours 3A\\Statistics in R\\PROJET\\Projet 2\\head_traumas_classification.yml') as file:
    data_loaded = yaml.safe_load(file)

cats = data_loaded.keys()
classes_cats = data_loaded['classes'].keys()
grades_cats = data_loaded['grades'].keys()

# %%
dataset.loc[:,'Shock index ph']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [Shock index ph] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-16fb498cf913> in <module>()
# ----> 1 dataset.loc[:,'Shock index ph']
#
# ...
